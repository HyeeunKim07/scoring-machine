# %% [markdown]
# <a href="https://colab.research.google.com/github/HyeeunKim07/scoring-machine/blob/main/1%ED%95%99%EB%85%84_2%ED%95%99%EA%B8%B0_%EA%B8%B0%EB%A7%90_%EA%B5%AD%EC%96%B4_%EB%8B%B5_%EC%B2%B4%ED%81%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('국어 답 채점하기\n복수정답 입력시 , 뒤에 띄어쓰기 하지 말아주세요')
score=0
total_questions=24

answer=input('1번 정답을 입력해주세요')
if answer.lower()=='4':
  score += 3.1
  print('correct')
else:
    print('The correct answer is 4')

answer=input('2번 정답을 입력해주세요')
if answer.lower()=='4':
  score += 3.8
  print('correct')
else:
    print('The correct answer is 4')

answer=input('3번 정답을 입력해주세요')
if answer.lower()=='3':
  score += 3.6
  print('correct')
else:
    print('The correct answer is 3')

answer=input('4번 정답을 입력해주세요')
if answer.lower()=='5':
  score += 3.9
  print('correct')
else:
    print('The correct answer is 5')

answer=input('5번 정답을 입력해주세요')
if answer.lower()=='3':
  score += 3.2
  print('correct')
else:
    print('The correct answer is 3')

answer=input('6번 정답을 입력해주세요')
if answer.lower()=='2':
  score += 2.2
  print('correct')
else:
    print('The correct answer is 2')

answer=input('7번 정답을 입력해주세요')
if answer.lower()=='3':
  score += 3.5
  print('correct')
else:
    print('The correct answer is 3')

answer=input('8번 정답을 입력해주세요')
if answer.lower()=='1':
  score += 3.7
  print('correct')
else:
    print('The correct answer is 1')

answer=input('9번 정답을 입력해주세요')
if answer.lower()=='1':
  score += 3.1
  print('correct')
else:
    print('The correct answer is 1')

answer=input('10번 정답을 입력해주세요')
if answer.lower()=='4':
  score += 3.2
  print('correct')
else:
    print('The correct answer is 4')

answer=input('11번 정답을 입력해주세요')
if answer.lower()=='4':
  score += 3.2
  print('correct')
else:
    print('The correct answer is 4')

answer=input('12번 정답을 입력해주세요')
if answer.lower()=='2':
  score += 3.2
  print('correct')
else:
    print('The correct answer is 2')

answer=input('13번 정답을 입력해주세요')
if answer.lower()=='3':
  score += 3.1
  print('correct')
else:
    print('The correct answer is 3')

answer=input('14번 정답을 입력해주세요')
if answer.lower()=='2':
  score += 3.3
  print('correct')
else:
    print('The correct answer is 2')

answer=input('15번 정답을 입력해주세요')
if answer.lower()=='3':
  score += 3.4
  print('correct')
else:
    print('The correct answer is 3')

answer=input('16번 정답을 입력해주세요')
if answer.lower()=='3':
  score += 3.5
  print('correct')
else:
    print('The correct answer is 3')

answer=input('17번 정답을 입력해주세요')
if answer.lower()=='1,3':
  score += 3.3
  print('correct')
else:
    print('The correct answer is 1,3')

answer=input('18번 정답을 입력해주세요')
if answer.lower()=='4':
  score += 3.2
  print('correct')
else:
    print('The correct answer is 4')

answer=input('19번 정답을 입력해주세요')
if answer.lower()=='4':
  score += 3.2
  print('correct')
else:
    print('The correct answer is 4')

answer=input('20번 정답을 입력해주세요')
if answer.lower()=='4,5':
  score += 3.4
  print('correct')
else:
    print('The correct answer is 4,5')

answer=input('21번 정답을 입력해주세요')
if answer.lower()=='2':
  score += 3.5
  print('correct')
else:
    print('The correct answer is 2')

answer=input('22번 정답을 입력해주세요')
if answer.lower()=='3,5':
  score += 3.6
  print('correct')
else:
    print('The correct answer is 3,5')

answer=input('23번 정답을 입력해주세요')
if answer.lower()=='5':
  score += 3.3
  print('correct')
else:
    print('The correct answer is 5')

answer=input('24번 정답을 입력해주세요')
if answer.lower()=='1':
  score += 3.5
  print('correct')
else:
    print('The correct answer is 1')

print('채점 완료! {score}점입니다')
# Out:
# 국어 답 채점하기
# 복수정답 입력시 , 뒤에 띄어쓰기 하지 말아주세요
# 1번 정답을 입력해주세요1
# The correct answer is 4
# 2번 정답을 입력해주세요1
# The correct answer is 4
# 3번 정답을 입력해주세요2
# The correct answer is 3
# 4번 정답을 입력해주세요2
# The correct answer is 5
# 5번 정답을 입력해주세요3
# correct
# 6번 정답을 입력해주세요3
# The correct answer is 2
# 7번 정답을 입력해주세요4
# The correct answer is 3
# 8번 정답을 입력해주세요4
# The correct answer is 1
# 9번 정답을 입력해주세요
# The correct answer is 1
# 10번 정답을 입력해주세요
# The correct answer is 4
# 11번 정답을 입력해주세요
# The correct answer is 4
# 12번 정답을 입력해주세요
# The correct answer is 2
# 13번 정답을 입력해주세요
# 14번 정답을 입력해주세요
# The correct answer is 3
# The correct answer is 2
# 15번 정답을 입력해주세요
# The correct answer is 3
# 16번 정답을 입력해주세요
# The correct answer is 3
# 17번 정답을 입력해주세요
# The correct answer is 1,3
# 18번 정답을 입력해주세요
# The correct answer is 4
# 19번 정답을 입력해주세요4
# correct
# 20번 정답을 입력해주세요
# The correct answer is 4,5
# 21번 정답을 입력해주세요
# The correct answer is 2
# 22번 정답을 입력해주세요4
# The correct answer is 3,5
# 23번 정답을 입력해주세요4
# ...
